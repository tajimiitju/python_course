# %% [markdown]
# # Importing pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '0.22.0'

# %% [markdown]
# # Series and DataFrames and importing data from csv and indexing loc and iloc

# %%
pd.Series(['aha','fsa','ertt'])
# Out:
# 0     aha
# 1     fsa
# 2    ertt
# dtype: object

# %%
a=pd.Series(['aha','fsa','ertt'])
a[2]
# Out:
# 'ertt'

# %%
a=pd.Series(['aha','fsa','ertt'],index=['a','b','c'])
a
# Out:
# a     aha
# b     fsa
# c    ertt
# dtype: object

# %%
a=pd.Series(['aha','fsa','ertt'],index=['a','b','c'])
a['a']
# Out:
# 'aha'

# %%
a.dtype
# Out:
# dtype('O')

# %%
a=pd.Series([1,2,3],index=['a','b','c'])
a.dtype
# Out:
# dtype('int64')

# %%
a=pd.Series([1,2,3],index=['a','b','c'],dtype='int32')
a.dtype
# Out:
# dtype('int32')

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C']) #proti column k alada series kore
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.set_index('A')
# Out:
#    B  C
# A
# 1  2  3
# 4  5  6
# 7  8  9

# %%
print(df)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C']) #proti column k alada series kore
df.set_index('A',inplace= True)
df
# Out:
#    B  C
# A
# 1  2  3
# 4  5  6
# 7  8  9

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=['A','B','C']) #proti column k alada series kore
df.set_index('A',inplace= True)
df.reset_index(inplace=True)
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
oo = pd.read_csv('olympics.csv')
#oo

# %%
oo = pd.read_csv('olympics.csv',skiprows=4) #shift+tab dile suggestion ase
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo = pd.read_csv('olympics.csv',skiprows=4,index_col='Edition')
oo
# Out:
#             City      Sport       Discipline                      Athlete  \
# Edition
# 1896      Athens   Aquatics         Swimming                HAJOS, Alfred
# 1896      Athens   Aquatics         Swimming             HERSCHMANN, Otto
# 1896      Athens   Aquatics         Swimming            DRIVAS, Dimitrios
# 1896      Athens   Aquatics         Swimming           MALOKINIS, Ioannis
# 1896      Athens   Aquatics         Swimming           CHASAPIS, Spiridon
# 1896      Athens   Aquatics         Swimming        CHOROPHAS, Efstathios
# 1896      Athens   Aquatics         Swimming                HAJOS, Alfred
# 1896      Athens   Aquatics         Swimming             ANDREOU, Joannis
# 1896      Athens   Aquatics         Swimming        CHOROPHAS, Efstathios
# 1896      Athens   Aquatics         Swimming                NEUMANN, Paul
# 1896      Athens   Aquatics         Swimming            PEPANOS, Antonios
# ...

# %%
oo.head() #first 5 ta dekhabe
# Out:
#            City     Sport Discipline             Athlete  NOC Gender  \
# Edition
# 1896     Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1896     Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 1896     Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 1896     Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 1896     Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                               Event Event_gender   Medal
# Edition
# 1896                 100m freestyle            M    Gold
# 1896                 100m freestyle            M  Silver
# 1896     100m freestyle for sailors            M  Bronze
# 1896     100m freestyle for sailors            M    Gold
# 1896     100m freestyle for sailors            M  Silver

# %%
oo.head(10) #first 10 ta dekhabe
# Out:
#            City     Sport Discipline                Athlete  NOC Gender  \
# Edition
# 1896     Athens  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1896     Athens  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 1896     Athens  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 1896     Athens  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 1896     Athens  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 1896     Athens  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 1896     Athens  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1896     Athens  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 1896     Athens  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 1896     Athens  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                               Event Event_gender   Medal
# Edition
# 1896                 100m freestyle            M    Gold
# ...

# %%
oo.head(2000).to_csv('new.csv') #first 2000 ta die new csv hobe

# %%
oo.head(2000).to_csv('new1.csv',index=False) #first 2000 ta die new csv hobe kono index thakbena

# %%
oo = pd.read_csv('olympics.csv',skiprows=4) #index uniq hote hobe json er jonno
oo.head(200).to_json('new.json')

# %%
oo.loc[7] #7no row er akta series dibe
# Out:
# City                      Athens
# Edition                     1896
# Sport                   Aquatics
# Discipline              Swimming
# Athlete         ANDREOU, Joannis
# NOC                          GRE
# Gender                       Men
# Event            1200m freestyle
# Event_gender                   M
# Medal                     Silver
# Name: 7, dtype: object

# %%
oo.loc[1:4] # 1 theke 4 er data frame dibe
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.iloc[1:4]
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %%
oo.iloc[1:4,2:5]
# Out:
#       Sport Discipline             Athlete
# 1  Aquatics   Swimming    HERSCHMANN, Otto
# 2  Aquatics   Swimming   DRIVAS, Dimitrios
# 3  Aquatics   Swimming  MALOKINIS, Ioannis

# %%
oo.iloc[1:4,0:5]
# Out:
#      City  Edition     Sport Discipline             Athlete
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis

# %%
oo.iloc[1:5,4:6]
# Out:
#               Athlete  NOC
# 1    HERSCHMANN, Otto  AUT
# 2   DRIVAS, Dimitrios  GRE
# 3  MALOKINIS, Ioannis  GRE
# 4  CHASAPIS, Spiridon  GRE

# %%
oo1 = oo.set_index('Edition')
#oo1
oo1.loc[2008] #2008 saler sob kisu nie asse
# Out:
#             City      Sport       Discipline                Athlete  NOC  \
# Edition
# 2008     Beijing   Aquatics           Diving         GALPERIN, Gleb  RUS
# 2008     Beijing   Aquatics           Diving       MITCHAM, Matthew  AUS
# 2008     Beijing   Aquatics           Diving            ZHOU, Luxin  CHN
# 2008     Beijing   Aquatics           Diving              WANG, Xin  CHN
# 2008     Beijing   Aquatics           Diving           CHEN, Ruolin  CHN
# 2008     Beijing   Aquatics           Diving        HEYMANS, Emilie  CAN
# 2008     Beijing   Aquatics           Diving               QIN, Kai  CHN
# 2008     Beijing   Aquatics           Diving              HE, Chong  CHN
# 2008     Beijing   Aquatics           Diving    DESPATIE, Alexandre  CAN
# 2008     Beijing   Aquatics           Diving             WU, Minxia  CHN
# 2008     Beijing   Aquatics           Diving          GUO, Jingjing  CHN
# 2008     Beijing   Aquatics           Diving       PAKHALINA, Julia  RUS
# ...

# %%
oo1.iloc[2008:2010] #2008 ar 2009 no row nie asse ---> iloc
# Out:
#               City     Sport  Discipline               Athlete  NOC Gender  \
# Edition
# 1912     Stockholm  Aquatics  Water polo  ANDERSSON, Robert T.  SWE    Men
# 1912     Stockholm  Aquatics  Water polo    ANDERSSON, Vilhelm  SWE    Men
#
#               Event Event_gender   Medal
# Edition
# 1912     water polo            M  Silver
# 1912     water polo            M  Silver

# %%
oo1.loc[2004:2008]  #2004 theke 2008 porjonto sob nie asbe ---> loc
# Out:
#             City      Sport       Discipline                Athlete  NOC  \
# Edition
# 2004      Athens   Aquatics           Diving            TIAN, Liang  CHN
# 2004      Athens   Aquatics           Diving                HU, Jia  CHN
# 2004      Athens   Aquatics           Diving           HELM, Mathew  AUS
# 2004      Athens   Aquatics           Diving          TOURKY, Loudy  AUS
# 2004      Athens   Aquatics           Diving     NEWBERY, Chantelle  AUS
# 2004      Athens   Aquatics           Diving             LAO, Lishi  CHN
# 2004      Athens   Aquatics           Diving         SAUTIN, Dmitry  RUS
# 2004      Athens   Aquatics           Diving               PENG, Bo  CHN
# 2004      Athens   Aquatics           Diving    DESPATIE, Alexandre  CAN
# 2004      Athens   Aquatics           Diving      PAKHALINA, Ioulia  RUS
# 2004      Athens   Aquatics           Diving          GUO, Jingjing  CHN
# 2004      Athens   Aquatics           Diving             WU, Minxia  CHN
# ...

# %%
#normal ta abar nie asio
nn = pd.read_csv('olympics.csv',skiprows=4) #shift+tab dile suggestion ase
nn.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#nn.City
nn['City'] #ei duta aki sob City nie asbe
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
# 5         Athens
# 6         Athens
# 7         Athens
# 8         Athens
# 9         Athens
# 10        Athens
# 11        Athens
# 12        Athens
# 13        Athens
# 14        Athens
# 15        Athens
# 16        Athens
# 17        Athens
# 18        Athens
# 19        Athens
# 20        Athens
# 21        Athens
# 22        Athens
# 23        Athens
# 24        Athens
# 25        Athens
# 26        Athens
# 27        Athens
# 28        Athens
# 29        Athens
#           ...
# 29186    Beijing
# 29187    Beijing
# 29188    Beijing
# 29189    Beijing
# 29190    Beijing
# 29191    Beijing
# 29192    Beijing
# 29193    Beijing
# 29194    Beijing
# 29195    Beijing
# 29196    Beijing
# 29197    Beijing
# 29198    Beijing
# 29199    Beijing
# 29200    Beijing
# 29201    Beijing
# 29202    Beijing
# 29203    Beijing
# 29204    Beijing
# 29205    Beijing
# 29206    Beijing
# ...

# %%
nn[['City','NOC','Athlete']]  #list chole asbe
# Out:
#           City  NOC                      Athlete
# 0       Athens  HUN                HAJOS, Alfred
# 1       Athens  AUT             HERSCHMANN, Otto
# 2       Athens  GRE            DRIVAS, Dimitrios
# 3       Athens  GRE           MALOKINIS, Ioannis
# 4       Athens  GRE           CHASAPIS, Spiridon
# 5       Athens  GRE        CHOROPHAS, Efstathios
# 6       Athens  HUN                HAJOS, Alfred
# 7       Athens  GRE             ANDREOU, Joannis
# 8       Athens  GRE        CHOROPHAS, Efstathios
# 9       Athens  AUT                NEUMANN, Paul
# 10      Athens  GRE            PEPANOS, Antonios
# 11      Athens  USA                LANE, Francis
# 12      Athens  HUN             SZOKOLYI, Alajos
# 13      Athens  USA                BURKE, Thomas
# 14      Athens  GER               HOFMANN, Fritz
# 15      Athens  USA               CURTIS, Thomas
# 16      Athens  GBR           GOULDING, Grantley
# 17      Athens  FRA            LERMUSIAUX, Albin
# ...

# %%
oo.Edition.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### TASK : List only the NOC column using both the ['..'] and dot notation. What type is this object? and see the type

# %%
nn['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
nn.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
# 5        GRE
# 6        HUN
# 7        GRE
# 8        GRE
# 9        AUT
# 10       GRE
# 11       USA
# 12       HUN
# 13       USA
# 14       GER
# 15       USA
# 16       GBR
# 17       FRA
# 18       AUS
# 19       USA
# 20       GBR
# 21       USA
# 22       USA
# 23       GRE
# 24       AUS
# 25       HUN
# 26       GRE
# 27       USA
# 28       GRE
# 29       USA
#         ...
# 29186    KAZ
# 29187    UZB
# 29188    RUS
# 29189    ARM
# 29190    KOR
# 29191    RUS
# 29192    AZE
# 29193    KAZ
# 29194    KGZ
# 29195    RUS
# 29196    AZE
# 29197    BLR
# 29198    UKR
# 29199    FRA
# 29200    KGZ
# 29201    FRA
# 29202    BUL
# 29203    GEO
# 29204    CHN
# 29205    TUR
# 29206    ITA
# 29207    HUN
# 29208    KAZ
# 29209    USA
# 29210    RUS
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo.NOC.dtype
oo['NOC'].dtype #duta ak kjaj korbe
# Out:
# dtype('O')

# %% [markdown]
# ## Overview and validation of data
# ### Shape

# %%
oo.shape #(row,column)
# Out:
# (29216, 10)

# %%
print("Total row= ",oo.shape[0])
print("Total column= ",oo.shape[1])
# Out:
# Total row=  29216
# Total columnb=  10

# %% [markdown]
# ### head() and tail()

# %%
oo.tail() #laster 5 ta asbe
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.tail(10) #laster 10 ta asbe... head eo aki vabe
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R      MINGUZZI, Andrea
# 29207  Beijing     2008  Wrestling  Wrestling Gre-R         FODOR, Zoltan
# 29208  Beijing     2008  Wrestling  Wrestling Gre-R       MAMBETOV, Asset
# 29209  Beijing     2008  Wrestling  Wrestling Gre-R         WHEELER, Adam
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R    KHUSHTOV, Aslanbek
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29206  ITA    Men   74 - 84kg            M    Gold
# 29207  HUN    Men   74 - 84kg            M  Silver
# ...

# %%
oo.NOC.tail(5) #laster 5 ta NOC
# Out:
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, dtype: object

# %% [markdown]
# ### info()

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %% [markdown]
# ### value_counts() Edition, Gender

# %%
nn.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
nn['Gender'].value_counts() #ekta series dibe count er
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
nn['Event_gender'].value_counts()
# Out:
# M    20067
# W     7278
# X     1871
# Name: Event_gender, dtype: int64

# %%
nn['Edition'].value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
nn['Edition'].value_counts(ascending=True) #vlue wise ascending hobe
# Out:
# 1896     151
# 1904     470
# 1900     512
# 1932     615
# 1928     710
# 1908     804
# 1948     814
# 1936     875
# 1960     882
# 1924     884
# 1956     885
# 1912     885
# 1952     889
# 1964    1010
# 1968    1031
# 1972    1185
# 1920    1298
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2004    1998
# 2000    2015
# 2008    2042
# Name: Edition, dtype: int64

# %%
nn['Discipline'].value_counts(ascending=True) #vlue wise ascending hobe
# Out:
# Roque                 3
# Jeu de Paume          3
# Basque Pelota         4
# Water Motorspor       5
# BMX                   6
# Croquet               8
# Rackets              10
# Vaulting             14
# Triathlon            18
# Trampoline           18
# Cricket              24
# Mountain Bike        24
# Ice Hockey           27
# Figure skating       27
# Golf                 30
# Beach volley.        48
# Lacrosse             59
# Polo                 66
# Taekwondo            80
# Canoe / Kayak S      90
# Rhythmic G.          93
# Tug of War           94
# Table Tennis        120
# Badminton           120
# Synchronized S.     153
# Modern Pentath.     174
# Softball            180
# Rugby               192
# Dressage            255
# Tennis              272
# Cycling Road        303
# Archery             305
# Jumping             312
# Eventing            313
# Baseball            335
# Diving              356
# Judo                435
# Weightlifting       548
# ...

# %% [markdown]
# ### sort_values() Athlete, Edition

# %%
nn['Athlete'].sort_values() #sorted series value wise
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
nn.sort_values('Edition') #edition wise sort hobe
# Out:
#           City  Edition       Sport       Discipline  \
# 0       Athens     1896    Aquatics         Swimming
# 97      Athens     1896  Gymnastics      Artistic G.
# 98      Athens     1896  Gymnastics      Artistic G.
# 99      Athens     1896  Gymnastics      Artistic G.
# 100     Athens     1896  Gymnastics      Artistic G.
# 101     Athens     1896  Gymnastics      Artistic G.
# 102     Athens     1896  Gymnastics      Artistic G.
# 103     Athens     1896  Gymnastics      Artistic G.
# 104     Athens     1896  Gymnastics      Artistic G.
# 105     Athens     1896  Gymnastics      Artistic G.
# 106     Athens     1896  Gymnastics      Artistic G.
# 107     Athens     1896  Gymnastics      Artistic G.
# 108     Athens     1896  Gymnastics      Artistic G.
# 109     Athens     1896  Gymnastics      Artistic G.
# 110     Athens     1896  Gymnastics      Artistic G.
# 111     Athens     1896  Gymnastics      Artistic G.
# 96      Athens     1896  Gymnastics      Artistic G.
# ...

# %%
nn.sort_values('Edition',ascending=False) #ulta
# Out:
#           City  Edition       Sport       Discipline  \
# 29215  Beijing     2008   Wrestling  Wrestling Gre-R
# 27859  Beijing     2008  Basketball       Basketball
# 27846  Beijing     2008  Basketball       Basketball
# 27847  Beijing     2008  Basketball       Basketball
# 27848  Beijing     2008  Basketball       Basketball
# 27849  Beijing     2008  Basketball       Basketball
# 27850  Beijing     2008  Basketball       Basketball
# 27851  Beijing     2008  Basketball       Basketball
# 27852  Beijing     2008  Basketball       Basketball
# 27853  Beijing     2008  Basketball       Basketball
# 27854  Beijing     2008  Basketball       Basketball
# 27855  Beijing     2008  Basketball       Basketball
# 27856  Beijing     2008  Basketball       Basketball
# 27857  Beijing     2008  Basketball       Basketball
# 27858  Beijing     2008  Basketball       Basketball
# 27860  Beijing     2008  Basketball       Basketball
# 27844  Beijing     2008  Basketball       Basketball
# ...

# %%
nn.sort_values(['Edition','Athlete'],ascending=False) #duita onujai
# Out:
#           City  Edition          Sport       Discipline  \
# 29007  Beijing     2008         Tennis           Tennis
# 28387  Beijing     2008     Gymnastics      Rhythmic G.
# 28977  Beijing     2008      Taekwondo        Taekwondo
# 28819  Beijing     2008        Sailing          Sailing
# 28095  Beijing     2008     Equestrian         Dressage
# 27900  Beijing     2008         Boxing           Boxing
# 28308  Beijing     2008     Gymnastics      Artistic G.
# 28314  Beijing     2008     Gymnastics      Artistic G.
# 28342  Beijing     2008     Gymnastics      Artistic G.
# 29172  Beijing     2008      Wrestling  Wrestling Free.
# 28396  Beijing     2008     Gymnastics      Rhythmic G.
# 28857  Beijing     2008       Shooting         Shooting
# 27394  Beijing     2008       Aquatics         Swimming
# 28989  Beijing     2008      Taekwondo        Taekwondo
# 28191  Beijing     2008        Fencing          Fencing
# 27341  Beijing     2008       Aquatics         Swimming
# ...

# %% [markdown]
# ### Filtering / Boolean indexing (finding all women with gold)

# %%
# == , != , & = and , | = or
nn.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
nn[(nn.Gender=='Women')&(nn.Medal=='Gold')].head(10) #women jara medal paise ... head deay first 10 ta, na dile sob asto
# Out:
#           City  Edition    Sport Discipline                      Athlete  NOC  \
# 417      Paris     1900     Golf       Golf        ABBOTT, Margaret Ives  USA
# 641      Paris     1900   Tennis     Tennis            COOPER, Charlotte  GBR
# 649      Paris     1900   Tennis     Tennis            COOPER, Charlotte  GBR
# 710   St Louis     1904  Archery    Archery        HOWELL, Matilda Scott  USA
# 713   St Louis     1904  Archery    Archery        HOWELL, Matilda Scott  USA
# 730   St Louis     1904  Archery    Archery        HOWELL, Matilda Scott  USA
# 731   St Louis     1904  Archery    Archery              POLLOCK, Jessie  USA
# 732   St Louis     1904  Archery    Archery               TAYLOR, Louise  USA
# 733   St Louis     1904  Archery    Archery              WOODRUFF, Laura  USA
# 1185    London     1908  Archery    Archery  NEWALL, Sybil Fenton Quenni  GBR
#
#      Gender                                    Event Event_gender Medal
# ...

# %% [markdown]
# ### String handling (Finding all Athletes having name Florence)

# %%
nn[nn.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# ### Task : In which events did 'OWENS, Jesse' win a medal?

# %%
nn[nn.Athlete=='OWENS, Jesse']
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %% [markdown]
# ### Task : Which country has won the most men's gold medals in badminton over the years? Sort the results alphabetically by the player's  names.

# %%
nn[(nn.Medal=='Gold')&(nn.Sport=='Badminton')&(nn.Gender=='Men')].sort_values('Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
nn[(nn.Medal=='Gold')&(nn.Sport=='Badminton')&(nn.Gender=='Men')].NOC.value_counts().head(1)
# Out:
# INA    8
# Name: NOC, dtype: int64

# %%
nn[(nn.Medal=='Gold')&(nn.Sport=='Badminton')&(nn.Gender=='Men')].sort_values('Athlete').NOC.value_counts().head(1)
# Out:
# INA    8
# Name: NOC, dtype: int64

# %% [markdown]
# ### Task : Which three countries have won the most medals in recent years (from 1984 to 2008)?

# %%
nn.NOC.value_counts().head(3)
# Out:
# USA    4335
# URS    2049
# GBR    1594
# Name: NOC, dtype: int64

# %%
nn.loc[1984:2008].NOC.value_counts().head(3)
# Out:
# GBR    9
# BEL    7
# ANZ    4
# Name: NOC, dtype: int64

# %%
nn.head(5)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
nn[(nn.Edition>=1984)&(nn.Edition<=2008)].NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %% [markdown]
# ### Task : Display the male gold medal winners for the 100m Track event over the years. List the results starting with the most recent. Show the Olympic City, Edition, Athlete and the country they represent.

# %%
nn[(nn.Medal=='Gold')&(nn.Event.str.contains('100m'))&(nn.Gender=='Men')].head(5)
# Out:
#          City  Edition      Sport Discipline             Athlete  NOC Gender  \
# 0      Athens     1896   Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 3      Athens     1896   Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 13     Athens     1896  Athletics  Athletics       BURKE, Thomas  USA    Men
# 231     Paris     1900  Athletics  Athletics     JARVIS, Francis  USA    Men
# 671  St Louis     1904   Aquatics   Swimming       BRACK, Walter  GER    Men
#
#                           Event Event_gender Medal
# 0                100m freestyle            M  Gold
# 3    100m freestyle for sailors            M  Gold
# 13                         100m            M  Gold
# 231                        100m            M  Gold
# 671             100m backstroke            M  Gold

# %%
nn[(nn.Medal=='Gold')&(nn.Event.str.contains('100m'))&(nn.Gender=='Men')].sort_values('Edition',ascending=False).head(10)
# Out:
#           City  Edition      Sport Discipline           Athlete  NOC Gender  \
# 27606  Beijing     2008  Athletics  Athletics     POWELL, Asafa  JAM    Men
# 27321  Beijing     2008   Aquatics   Swimming      CROCKER, Ian  USA    Men
# 27212  Beijing     2008   Aquatics   Swimming    PEIRSOL, Aaron  USA    Men
# 27218  Beijing     2008   Aquatics   Swimming  KITAJIMA, Kosuke  JPN    Men
# 27224  Beijing     2008   Aquatics   Swimming   PHELPS, Michael  USA    Men
# 27231  Beijing     2008   Aquatics   Swimming    BERNARD, Alain  FRA    Men
# 27287  Beijing     2008   Aquatics   Swimming    ADRIAN, Nathan  USA    Men
# 27288  Beijing     2008   Aquatics   Swimming     GREVERS, Matt  USA    Men
# 27289  Beijing     2008   Aquatics   Swimming     JONES, Cullen  USA    Men
# 27291  Beijing     2008   Aquatics   Swimming   PHELPS, Michael  USA    Men
#
#                         Event Event_gender Medal
# 27606            4x100m relay            M  Gold
# ...

# %%
nn[(nn.Medal=='Gold')&(nn.Event.str.contains('100m'))&(nn.Gender=='Men')].sort_values('Edition',ascending=False)[['City', 'Edition', 'Athlete','NOC']]
# Out:
#             City  Edition                        Athlete  NOC
# 27606    Beijing     2008                  POWELL, Asafa  JAM
# 27321    Beijing     2008                   CROCKER, Ian  USA
# 27212    Beijing     2008                 PEIRSOL, Aaron  USA
# 27218    Beijing     2008               KITAJIMA, Kosuke  JPN
# 27224    Beijing     2008                PHELPS, Michael  USA
# 27231    Beijing     2008                 BERNARD, Alain  FRA
# 27287    Beijing     2008                 ADRIAN, Nathan  USA
# 27288    Beijing     2008                  GREVERS, Matt  USA
# 27289    Beijing     2008                  JONES, Cullen  USA
# 27291    Beijing     2008                PHELPS, Michael  USA
# 27292    Beijing     2008            WEBER-GALE, Garrett  USA
# 27293    Beijing     2008          WILDMAN-TOBRINER, Ben  USA
# 27290    Beijing     2008                   LEZAK, Jason  USA
# 27322    Beijing     2008                 GANGLOFF, Mark  USA
# ...
